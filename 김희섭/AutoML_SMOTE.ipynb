# %%
import pycaret
from pycaret.classification import *
import numpy as np
import pandas as pd
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv('train_ver_2.csv')
test = pd.read_csv('test_ver_2.csv')

# %%
train, val = train_test_split(train, test_size=0.2, random_state=42)

# %%
train.shape
# Out:
# (1412, 21)

# %%
train['Response'].value_counts()
# Out:
# Response
# 0    1204
# 1     208
# Name: count, dtype: int64

# %%
val['Response'].value_counts()
# Out:
# Response
# 0    297
# 1     57
# Name: count, dtype: int64

# %%
test['Response'].value_counts()
# Out:
# Response
# 0    376
# 1     66
# Name: count, dtype: int64

# %%
train_smote = setup(data = train, target = 'Response', fix_imbalance = True)
# Out:
# <style type="text/css">
# #T_76263_row9_col1, #T_76263_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_76263">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76263_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_76263_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76263_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76263_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_76263_row0_col1" class="data row0 col1" >2791</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_76263_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_76263_row1_col1" class="data row1 col1" >Response</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_76263_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_76263_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_76263_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_76263_row3_col1" class="data row3 col1" >(1412, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_76263_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_76263_row4_col1" class="data row4 col1" >(2108, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_76263_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_76263_row5_col1" class="data row5 col1" >(1684, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_76263_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_76263_row6_col1" class="data row6 col1" >(424, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_76263_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_76263_row7_col1" class="data row7 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_76263_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_76263_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_76263_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_76263_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_76263_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_76263_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_76263_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_76263_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_76263_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_76263_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_76263_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_76263_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_76263_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_76263_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_76263_row15_col0" class="data row15 col0" >Fix imbalance</td>
#       <td id="T_76263_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_76263_row16_col0" class="data row16 col0" >Fix imbalance method</td>
#       <td id="T_76263_row16_col1" class="data row16 col1" >SMOTE</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_76263_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_76263_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_76263_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_76263_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_76263_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_76263_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_76263_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_76263_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_76263_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_76263_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_76263_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_76263_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_76263_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_76263_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_76263_row23_col1" class="data row23 col1" >82cf</td>
#     </tr>
#   </tbody>
# </table>

# %%
get_config('y_transformed').value_counts()
# Out:
# Response
# 0    1204
# 1     904
# Name: count, dtype: int64

# %%
over_sam_train = pd.concat([get_config('X_transformed'), get_config('y_transformed')], axis=1)
over_sam_train.head()
# Out:
#       Education_Graduation  Education_2n Cycle  Education_Master  \
# 1274                   1.0                 0.0               0.0
# 1733                   0.0                 1.0               0.0
# 1728                   0.0                 0.0               1.0
# 1511                   1.0                 0.0               0.0
# 1094                   0.0                 0.0               1.0
#
#       Education_PhD  Education_Basic  Marital_Status_Married  \
# 1274            0.0              0.0                     1.0
# 1733            0.0              0.0                     0.0
# 1728            0.0              0.0                     0.0
# 1511            0.0              0.0                     1.0
# 1094            0.0              0.0                     1.0
#
#       Marital_Status_Single  Marital_Status_Together  Marital_Status_Widow  \
# 1274                    0.0                      0.0                   0.0
# 1733                    1.0                      0.0                   0.0
# 1728                    1.0                      0.0                   0.0
# 1511                    0.0                      0.0                   0.0
# 1094                    0.0                      0.0                   0.0
#
#       Marital_Status_Divorced  ...  MntSweetProducts  MntGoldProds  \
# 1274                      0.0  ...               8.0          24.0
# 1733                      0.0  ...               1.0           8.0
# 1728                      0.0  ...             144.0          96.0
# 1511                      0.0  ...               7.0          57.0
# 1094                      0.0  ...               6.0          29.0
#
#       NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 1274                3.0              2.0                  1.0
# 1733                1.0              1.0                  0.0
# 1728                1.0              3.0                  4.0
# 1511                1.0              9.0                  2.0
# 1094                3.0             10.0                  4.0
#
#       NumStorePurchases  NumWebVisitsMonth  Complain   Age  Response
# 1274                3.0                6.0       0.0  55.0         0
# 1733                3.0                6.0       0.0  43.0         0
# 1728               10.0                1.0       0.0  32.0         1
# 1511                9.0                5.0       0.0  51.0         0
# 1094                5.0                8.0       0.0  67.0         0
#
# [5 rows x 29 columns]

# %%
val_smote = setup(data = val, target = 'Response', fix_imbalance = False)
# Out:
# <style type="text/css">
# #T_f3737_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f3737">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3737_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f3737_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3737_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f3737_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f3737_row0_col1" class="data row0 col1" >7584</td>
#     </tr>
#     <tr>
#       <th id="T_f3737_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f3737_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f3737_row1_col1" class="data row1 col1" >Response</td>
#     </tr>
#     <tr>
#       <th id="T_f3737_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f3737_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f3737_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_f3737_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f3737_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f3737_row3_col1" class="data row3 col1" >(354, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_f3737_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f3737_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f3737_row4_col1" class="data row4 col1" >(354, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_f3737_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f3737_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f3737_row5_col1" class="data row5 col1" >(247, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_f3737_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f3737_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f3737_row6_col1" class="data row6 col1" >(107, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_f3737_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f3737_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_f3737_row7_col1" class="data row7 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_f3737_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f3737_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_f3737_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f3737_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f3737_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_f3737_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f3737_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f3737_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_f3737_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f3737_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f3737_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_f3737_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f3737_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f3737_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_f3737_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f3737_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f3737_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_f3737_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_f3737_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f3737_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_f3737_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f3737_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f3737_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_f3737_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_f3737_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f3737_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_f3737_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f3737_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f3737_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_f3737_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f3737_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f3737_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_f3737_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f3737_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f3737_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_f3737_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f3737_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f3737_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_f3737_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f3737_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f3737_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_f3737_row21_col1" class="data row21 col1" >7c55</td>
#     </tr>
#   </tbody>
# </table>

# %%
get_config('y_transformed').value_counts()
# Out:
# Response
# 0    297
# 1     57
# Name: count, dtype: int64

# %%
over_sam_val = pd.concat([get_config('X_transformed'), get_config('y_transformed')], axis=1)
over_sam_val.head()
# Out:
#       Education_PhD  Education_Master  Education_Graduation  Education_Basic  \
# 123             1.0               0.0                   0.0              0.0
# 76              1.0               0.0                   0.0              0.0
# 1313            0.0               1.0                   0.0              0.0
# 1023            1.0               0.0                   0.0              0.0
# 1269            0.0               0.0                   1.0              0.0
#
#       Education_2n Cycle  Marital_Status_Together  Marital_Status_Married  \
# 123                  0.0                      1.0                     0.0
# 76                   0.0                      0.0                     1.0
# 1313                 0.0                      1.0                     0.0
# 1023                 0.0                      0.0                     1.0
# 1269                 0.0                      0.0                     0.0
#
#       Marital_Status_Divorced  Marital_Status_Single  Marital_Status_Widow  \
# 123                       0.0                    0.0                   0.0
# 76                        0.0                    0.0                   0.0
# 1313                      0.0                    0.0                   0.0
# 1023                      0.0                    0.0                   0.0
# 1269                      1.0                    0.0                   0.0
#
#       ...  MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# 123   ...               2.0          15.0                4.0              3.0
# 76    ...               0.0         144.0                1.0              8.0
# 1313  ...              92.0          15.0                1.0              4.0
# 1023  ...              38.0         172.0                1.0              4.0
# 1269  ...             123.0         114.0                2.0              4.0
#
#       NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  Complain  \
# 123                   0.0                4.0                4.0       0.0
# 76                    5.0                4.0                7.0       0.0
# 1313                  6.0               13.0                2.0       0.0
# 1023                 10.0                5.0                3.0       0.0
# 1269                  7.0               13.0                2.0       0.0
#
#        Age  Response
# 123   65.0         0
# 76    54.0         1
# 1313  52.0         0
# 1023  35.0         0
# 1269  56.0         0
#
# [5 rows x 29 columns]

# %%
test_smote = setup(data = test, target = 'Response', fix_imbalance = False)
# Out:
# <style type="text/css">
# #T_ec2a5_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ec2a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec2a5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ec2a5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec2a5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ec2a5_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ec2a5_row0_col1" class="data row0 col1" >7072</td>
#     </tr>
#     <tr>
#       <th id="T_ec2a5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ec2a5_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ec2a5_row1_col1" class="data row1 col1" >Response</td>
#     </tr>
#     <tr>
#       <th id="T_ec2a5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ec2a5_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_ec2a5_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_ec2a5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ec2a5_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_ec2a5_row3_col1" class="data row3 col1" >(442, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_ec2a5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ec2a5_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_ec2a5_row4_col1" class="data row4 col1" >(442, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_ec2a5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ec2a5_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_ec2a5_row5_col1" class="data row5 col1" >(309, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_ec2a5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ec2a5_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_ec2a5_row6_col1" class="data row6 col1" >(133, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_ec2a5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ec2a5_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_ec2a5_row7_col1" class="data row7 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_ec2a5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ec2a5_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_ec2a5_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ec2a5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ec2a5_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_ec2a5_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ec2a5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ec2a5_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_ec2a5_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_ec2a5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ec2a5_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_ec2a5_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_ec2a5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ec2a5_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_ec2a5_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_ec2a5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ec2a5_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_ec2a5_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_ec2a5_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ec2a5_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_ec2a5_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_ec2a5_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ec2a5_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_ec2a5_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_ec2a5_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ec2a5_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_ec2a5_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ec2a5_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ec2a5_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_ec2a5_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_ec2a5_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ec2a5_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_ec2a5_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ec2a5_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ec2a5_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_ec2a5_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ec2a5_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_ec2a5_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_ec2a5_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_ec2a5_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_ec2a5_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_ec2a5_row21_col1" class="data row21 col1" >a801</td>
#     </tr>
#   </tbody>
# </table>

# %%
get_config('y_transformed').value_counts()
# Out:
# Response
# 0    376
# 1     66
# Name: count, dtype: int64

# %%
over_sam_test = pd.concat([get_config('X_transformed'), get_config('y_transformed')], axis=1)
over_sam_test.head()
# Out:
#      Education_PhD  Education_Graduation  Education_Master  \
# 308            1.0                   0.0               0.0
# 385            0.0                   1.0               0.0
# 38             0.0                   0.0               1.0
# 270            0.0                   1.0               0.0
# 61             1.0                   0.0               0.0
#
#      Education_2n Cycle  Education_Basic  Marital_Status_Together  \
# 308                 0.0              0.0                      1.0
# 385                 0.0              0.0                      1.0
# 38                  0.0              0.0                      1.0
# 270                 0.0              0.0                      0.0
# 61                  0.0              0.0                      1.0
#
#      Marital_Status_Single  Marital_Status_Married  Marital_Status_Widow  \
# 308                    0.0                     0.0                   0.0
# 385                    0.0                     0.0                   0.0
# 38                     0.0                     0.0                   0.0
# 270                    1.0                     0.0                   0.0
# 61                     0.0                     0.0                   0.0
#
#      Marital_Status_Divorced  ...  MntSweetProducts  MntGoldProds  \
# 308                      0.0  ...               1.0           2.0
# 385                      0.0  ...              49.0          49.0
# 38                       0.0  ...              20.0          50.0
# 270                      0.0  ...             102.0         102.0
# 61                       0.0  ...              82.0          71.0
#
#      NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 308                0.0              0.0                  0.0
# 385                1.0              6.0                  7.0
# 38                 2.0              3.0                  5.0
# 270               10.0              4.0                  6.0
# 61                 1.0              9.0                  3.0
#
#      NumStorePurchases  NumWebVisitsMonth  Complain   Age  Response
# 308                1.0                1.0       0.0  47.0         0
# 385               12.0                3.0       0.0  76.0         0
# 38                 7.0                7.0       0.0  47.0         1
# 270                9.0                7.0       0.0  53.0         0
# 61                13.0                4.0       0.0  76.0         0
#
# [5 rows x 29 columns]

# %%
over_sam_train['Response'].value_counts(),over_sam_val['Response'].value_counts(), over_sam_test['Response'].value_counts()
# Out:
# (Response
#  0    1204
#  1     904
#  Name: count, dtype: int64,
#  Response
#  0    297
#  1     57
#  Name: count, dtype: int64,
#  Response
#  0    376
#  1     66
#  Name: count, dtype: int64)

# %%
over_sam_train.to_csv('train_SMOTE.csv', index=False)
over_sam_val.to_csv('val_SMOTE.csv', index=False)
over_sam_test.to_csv('test_SMOTE.csv', index=False)
